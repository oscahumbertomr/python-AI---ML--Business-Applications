# %%
# Libraries to help with reading and manipulating data
import numpy as np
import pandas as pd

# Libraries to help with data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Command to tell Python to actually display the graphs
# %matplotlib inline

# %%
df = pd.read_csv('./data/Automobile.csv')

df
# Out:
#      symboling  normalized_losses         make fuel_type aspiration  \
# 0            3                168  alfa-romero       gas        std
# 1            3                168  alfa-romero       gas        std
# 2            1                168  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 196         -1                 95        volvo       gas        std
# 197         -1                 95        volvo       gas      turbo
# 198         -1                 95        volvo       gas        std
# 199         -1                 95        volvo    diesel      turbo
# 200         -1                 95        volvo       gas      turbo
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# 0               two  convertible          rwd           front        88.6
# 1               two  convertible          rwd           front        88.6
# 2               two    hatchback          rwd           front        94.5
# 3              four        sedan          fwd           front        99.8
# 4              four        sedan          4wd           front        99.4
# ..              ...          ...          ...             ...         ...
# 196            four        sedan          rwd           front       109.1
# 197            four        sedan          rwd           front       109.1
# 198            four        sedan          rwd           front       109.1
# 199            four        sedan          rwd           front       109.1
# 200            four        sedan          rwd           front       109.1
#
#      ...  engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# 0    ...          130         mpfi  3.47    2.68               9.0        111
# 1    ...          130         mpfi  3.47    2.68               9.0        111
# 2    ...          152         mpfi  2.68    3.47               9.0        154
# 3    ...          109         mpfi  3.19    3.40              10.0        102
# 4    ...          136         mpfi  3.19    3.40               8.0        115
# ..   ...          ...          ...   ...     ...               ...        ...
# 196  ...          141         mpfi  3.78    3.15               9.5        114
# 197  ...          141         mpfi  3.78    3.15               8.7        160
# 198  ...          173         mpfi  3.58    2.87               8.8        134
# 199  ...          145          idi  3.01    3.40              23.0        106
# 200  ...          141         mpfi  3.78    3.15               9.5        114
#
#      peak_rpm city_mpg  highway_mpg  price
# 0        5000       21           27  13495
# 1        5000       21           27  16500
# 2        5000       19           26  16500
# 3        5500       24           30  13950
# 4        5500       18           22  17450
# ..        ...      ...          ...    ...
# 196      5400       23           28  16845
# 197      5300       19           25  19045
# 198      5500       18           23  21485
# 199      4800       26           27  22470
# 200      5400       19           25  22625
#
# [201 rows x 26 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 26 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   symboling            201 non-null    int64
#  1   normalized_losses    201 non-null    int64
#  2   make                 201 non-null    object
#  3   fuel_type            201 non-null    object
#  4   aspiration           201 non-null    object
#  5   number_of_doors      201 non-null    object
#  6   body_style           201 non-null    object
#  7   drive_wheels         201 non-null    object
#  8   engine_location      201 non-null    object
#  9   wheel_base           201 non-null    float64
#  10  length               201 non-null    float64
#  11  width                201 non-null    float64
#  12  height               201 non-null    float64
#  13  curb_weight          201 non-null    int64
#  14  engine_type          201 non-null    object
#  15  number_of_cylinders  201 non-null    object
#  16  engine_size          201 non-null    int64
#  17  fuel_system          201 non-null    object
#  18  bore                 201 non-null    float64
#  19  stroke               201 non-null    float64
#  20  compression_ratio    201 non-null    float64
#  21  horsepower           201 non-null    int64
#  22  peak_rpm             201 non-null    int64
#  23  city_mpg             201 non-null    int64
#  24  highway_mpg          201 non-null    int64
#  25  price                201 non-null    int64
# dtypes: float64(7), int64(9), object(10)
# memory usage: 41.0+ KB

# %%
df['make'].value_counts()
# Out:
# toyota           32
# nissan           18
# mazda            17
# mitsubishi       13
# honda            13
# volkswagen       12
# subaru           12
# peugot           11
# volvo            11
# dodge             9
# mercedes-benz     8
# bmw               8
# plymouth          7
# audi              6
# saab              6
# porsche           4
# jaguar            3
# chevrolet         3
# alfa-romero       3
# isuzu             2
# renault           2
# mercury           1
# Name: make, dtype: int64

# %%
y = df['make'].value_counts()
x = y.index
plt.bar(x,y)
plt.title('test plt')
plt.xticks(rotation=90)
for i in range(len(x)):
    plt.text(i, y[i]+1, str(y[i]), ha='center')
plt.show()

# %%
sns.histplot(data=df,x='price');

# %%
plt.title('Histogram: Pice')
plt.xlim(3000, 50000)
plt.ylim(0, 70)
plt.xlabel('Price of cars')
plt.ylabel('Frequency')
sns.histplot(data=df,x='price',color='orange')
# Out:
# <Axes: title={'center': 'Histogram: Pice'}, xlabel='Price of cars', ylabel='Frequency'>

# %%
sns.histplot(data=df,x='price',color='orange', kde='True')
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
sns.boxplot(data=df, x='bore')
# Out:
# <Axes: xlabel='bore'>

# %%
sns.histplot(data=df,x='bore', kde=True)
# Out:
# <Axes: xlabel='bore', ylabel='Count'>

# %%
sns.boxplot(data=df,x='body_style', y='price')
# Out:
# <Axes: xlabel='body_style', ylabel='price'>

# %%
sns.countplot(data=df,x='body_style')
# Out:
# <Axes: xlabel='body_style', ylabel='count'>

# %%
sns.countplot(data=df,x='body_style',hue='fuel_type')
# Out:
# <Axes: xlabel='body_style', ylabel='count'>

# %%
sns.countplot(data=df,x='make')
# Out:
# <Axes: xlabel='make', ylabel='count'>

# %%
plt.figure(figsize=(20,7))
sns.countplot(data=df,x='make')
plt.xticks(rotation=70);

# %%
sns.lineplot(data=df,x='body_style', y='price')
# Out:
# <Axes: xlabel='body_style', ylabel='price'>

# %%
flights = sns.load_dataset('flights')

flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
flights[flights['month']=='Jul']['passengers'].mean()
# Out:
# 351.3333333333333

# %%
sns.lineplot(data=flights, x='month', y = 'passengers')
# Out:
# <Axes: xlabel='month', ylabel='passengers'>

# %%
sns.lineplot(data=flights, x='month', y = 'passengers', hue = 'year')
# Out:
# <Axes: xlabel='month', ylabel='passengers'>

# %%
fmri = sns.load_dataset('fmri')

fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
sns.lineplot(data=fmri, x='timepoint', y='signal')
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
sns.lineplot(data=fmri, x='timepoint', y='signal',hue='region',style='region',ci=False);
# Out:
# /tmp/ipykernel_717/765172312.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.lineplot(data=fmri, x='timepoint', y='signal',hue='region',style='region',ci=False);

# %%
sns.lineplot(data=fmri, x='timepoint', y='signal',hue='region',style='region',ci=False, markers=True)
# Out:
# /tmp/ipykernel_717/1507256417.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.lineplot(data=fmri, x='timepoint', y='signal',hue='region',style='region',ci=False, markers=True)
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
sns.scatterplot(data=df, x='engine_size', y='horsepower')
# Out:
# <Axes: xlabel='engine_size', ylabel='horsepower'>

# %%
sns.scatterplot(data=df, x='engine_size', y='horsepower',hue='fuel_type', style='fuel_type');

# %%
sns.jointplot(data=df, x='engine_size', y='horsepower');

# %%
sns.jointplot(data=df, x='engine_size', y='horsepower',hue='fuel_type');

# %%
sns.jointplot(data=df, x='engine_size', y='horsepower', kind='hex');

# %%
sns.jointplot(data=df, x='engine_size', y='horsepower', kind='kde');

# %%
sns.jointplot(data=df, x='engine_size', y='horsepower', kind='kde', fill=True);

# %%
sns.jointplot(data=df, x='price', y='city_mpg', kind='reg');

# %%
sns.violinplot(data=df,x='horsepower')
# Out:
# <Axes: xlabel='horsepower'>

# %%
sns.histplot(data=df,x='horsepower')
# Out:
# <Axes: xlabel='horsepower', ylabel='Count'>

# %%
sns.violinplot(data=df,x='fuel_type', y='horsepower', orient='v')
# Out:
# <Axes: xlabel='fuel_type', ylabel='horsepower'>

# %%
sns.violinplot(data=df,x='engine_size', y='fuel_type')
# Out:
# <Axes: xlabel='engine_size', ylabel='fuel_type'>

# %%
sns.violinplot(data=df,x='body_style', y='engine_size')
# Out:
# <Axes: xlabel='body_style', ylabel='engine_size'>

# %%
sns.violinplot(data=df,x='body_style', y='engine_size', palette='bright')
# Out:
# <Axes: xlabel='body_style', ylabel='engine_size'>

# %%
sns.violinplot(data=df,x='body_style', y='engine_size', palette='colorblind')
# Out:
# <Axes: xlabel='body_style', ylabel='engine_size'>

# %%
sns.stripplot(data=df,x='engine_size')
# Out:
# <Axes: xlabel='engine_size'>

# %%
plt.figure(figsize=(20,7))
sns.stripplot(data=df,x='body_style',y='engine_size', palette='colorblind')
# Out:
# /tmp/ipykernel_717/3463988000.py:2: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.stripplot(data=df,x='body_style',y='engine_size', palette='colorblind')
# <Axes: xlabel='body_style', ylabel='engine_size'>

# %%
plt.figure(figsize=(20,7))
sns.stripplot(data=df,x='body_style',y='engine_size', palette='colorblind', jitter=True)
# Out:
# /tmp/ipykernel_717/2754743348.py:2: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.stripplot(data=df,x='body_style',y='engine_size', palette='colorblind', jitter=True)
# <Axes: xlabel='body_style', ylabel='engine_size'>

# %%
plt.figure(figsize=(10,7))
sns.stripplot(data=df,x='fuel_type',y='engine_size', hue='number_of_doors', jitter=True)
# Out:
# <Axes: xlabel='fuel_type', ylabel='engine_size'>

# %%
plt.figure(figsize=(10,7))
sns.stripplot(data=df,x='number_of_doors',y='price', jitter=True, palette='colorblind')
# Out:
# /tmp/ipykernel_717/3132524767.py:2: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.stripplot(data=df,x='number_of_doors',y='price', jitter=True, palette='colorblind')
# <Axes: xlabel='number_of_doors', ylabel='price'>

# %%
plt.figure(figsize=(10,7))
sns.swarmplot(data=df,x='number_of_doors',y='price', palette='colorblind')
# Out:
# /tmp/ipykernel_717/2198828526.py:2: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.swarmplot(data=df,x='number_of_doors',y='price', palette='colorblind')
# <Axes: xlabel='number_of_doors', ylabel='price'>

# %%
plt.figure(figsize=(10,7))
sns.swarmplot(data=df,x='fuel_type',y='price', hue='number_of_doors')
# Out:
# <Axes: xlabel='fuel_type', ylabel='price'>

# %%
sns.swarmplot(data=df,x='fuel_type',y='price', hue='number_of_doors', dodge=True)
# Out:
# <Axes: xlabel='fuel_type', ylabel='price'>

# %%
sns.pairplot(data=df[['normalized_losses','wheel_base','curb_weight','engine_size','price','peak_rpm']],corner=False)

# %%
sns.pairplot(data=df[['normalized_losses','wheel_base','curb_weight','engine_size','price','peak_rpm']])

# %%
data=df[['wheel_base','curb_weight','engine_size','price']].corr()
data
# Out:
#              wheel_base  curb_weight  engine_size     price
# wheel_base     1.000000     0.782097     0.572027  0.584642
# curb_weight    0.782097     1.000000     0.849072  0.834415
# engine_size    0.572027     0.849072     1.000000  0.872335
# price          0.584642     0.834415     0.872335  1.000000
